# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(42)

data = pd.DataFrame(
    np.random.rand(20, 10),
    columns=[f"Gene_{i}" for i in range(10)]
)

labels = pd.DataFrame({
    "sample": [f"S{i}" for i in range(20)],
    "group": ["Cancer"]*10 + ["Normal"]*10
})

data.head()
# Out:
#      Gene_0    Gene_1    Gene_2    Gene_3    Gene_4    Gene_5    Gene_6  \
# 0  0.374540  0.950714  0.731994  0.598658  0.156019  0.155995  0.058084
# 1  0.020584  0.969910  0.832443  0.212339  0.181825  0.183405  0.304242
# 2  0.611853  0.139494  0.292145  0.366362  0.456070  0.785176  0.199674
# 3  0.607545  0.170524  0.065052  0.948886  0.965632  0.808397  0.304614
# 4  0.122038  0.495177  0.034389  0.909320  0.258780  0.662522  0.311711
#
#      Gene_7    Gene_8    Gene_9
# 0  0.866176  0.601115  0.708073
# 1  0.524756  0.431945  0.291229
# 2  0.514234  0.592415  0.046450
# 3  0.097672  0.684233  0.440152
# 4  0.520068  0.546710  0.184854

# %%
from sklearn.decomposition import PCA

# %%
X = data.values
y = labels["group"].values

# %%
pca = PCA(n_components=2)
components = pca.fit_transform(X)

pca_df = pd.DataFrame(components, columns=["PC1", "PC2"])
pca_df["group"] = y

pca_df.head()
# Out:
#         PC1       PC2   group
# 0  0.800862  0.044613  Cancer
# 1  0.795710  0.163091  Cancer
# 2 -0.382311  0.036334  Cancer
# 3 -0.889482  0.232549  Cancer
# 4 -0.156426  0.329175  Cancer

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,6))
sns.scatterplot(data=pca_df, x="PC1", y="PC2", hue="group")

plt.title("PCA: Cancer vs Normal Samples")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")

plt.show()

# %%
print("Cancer Gene Expression Explorer")
# Out:
# Cancer Gene Expression Explorer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.rand(100, 10)

df = pd.DataFrame(
    data,
    columns=[f"Gene_{i}" for i in range(10)]
)

df.head()
# Out:
#      Gene_0    Gene_1    Gene_2    Gene_3    Gene_4    Gene_5    Gene_6  \
# 0  0.642032  0.084140  0.161629  0.898554  0.606429  0.009197  0.101472
# 1  0.548734  0.691895  0.651961  0.224269  0.712179  0.237249  0.325400
# 2  0.657613  0.568309  0.093675  0.367716  0.265202  0.243990  0.973011
# 3  0.794811  0.502637  0.576904  0.492518  0.195243  0.722452  0.280772
# 4  0.940459  0.953929  0.914864  0.370159  0.015457  0.928319  0.428184
#
#      Gene_7    Gene_8    Gene_9
# 0  0.663502  0.005062  0.160808
# 1  0.746491  0.649633  0.849223
# 2  0.393098  0.892047  0.631139
# 3  0.024316  0.645472  0.177111
# 4  0.966655  0.963620  0.853009

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

pca_result = pca.fit_transform(df)

print(pca_result[:5])
# Out:
# [[-0.8231104   0.39705792]
#  [ 0.2190868   0.17424953]
#  [-0.10649985 -0.39539654]
#  [ 0.13142101  0.02595805]
#  [ 0.68122469 -0.11202726]]

# %%
plt.figure(figsize=(6, 4))

plt.scatter(
    pca_result[:, 0],
    pca_result[:, 1]
)

plt.title("PCA of Gene Expression Data")
plt.xlabel("PC1")
plt.ylabel("PC2")

plt.show()
